# %%
pip install openpyxl

# %%
import openpyxlwb = openpyxl.Workbook()hoja = wb.activehoja.title = "Valores"hoja.append(('id','text','context'))

# %%
import json# Lee el archivo JSON y carga los datos en un diccionariowith open('./data/Meneame/Meneame/Corpus/batch-FASE4.json', 'r', encoding='utf-8') as file:    data = json.load(file)# Ahora puedes acceder a los datos en forma de diccionario# Por ejemplo, para acceder a la lista de publicaciones (posts):posts = data['posts']

# %%
for entrada in posts: #Añadir todos los datos    hoja.append((entrada['id'],entrada['text'],entrada['context']))

# %%
wb.save('datos.xlsx')
